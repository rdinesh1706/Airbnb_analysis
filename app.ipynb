# %%
import pymongo
import pandas as pd
pd.set_option("display.max_columns", None)
import warnings
warnings.filterwarnings("ignore")

# %%
# from pymongo.mongo_client import MongoClient
# from pymongo.server_api import ServerApi
# import urllib
# import certifi

# uri = "mongodb+srv://rdinesh1702:{password}@cluster0.gfpts1u.mongodb.net/?retryWrites=true&w=majority"

# # mongo = pymongo(app,tlsCAFile=certifi.where())
# # Create a new client and connect to the server
# client = MongoClient(uri, server_api=ServerApi('1'))

# # Send a ping to confirm a successful connection
# try:
#     client.admin.command('ping')
#     print("Pinged your deployment. You successfully connected to MongoDB!")
# except Exception as e:
#     print(e)
# Out:
# ac-gas3qtj-shard-00-02.gfpts1u.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:997) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),ac-gas3qtj-shard-00-00.gfpts1u.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:997) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),ac-gas3qtj-shard-00-01.gfpts1u.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:997) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65bc9a05730f2a7d3c4322c8, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-gas3qtj-shard-00-00.gfpts1u.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('ac-gas3qtj-shard-00-00.gfpts1u.mongodb.net:27017: [SSL: CER
# ...

# %%
# import ssl
# from pymongo.mongo_client import MongoClient
# uri = "mongodb+srv://rdinesh1702:rdx1717@cluster0.gfpts1u.mongodb.net/?retryWrites=true&w=majority"
# # Create a new client and connect to the server
# client = MongoClient(uri)


# # Send a ping to confirm a successful connection
# session.get("https://python.org", ssl=False)
# try:
#     client.admin.command('ping')
#     print("Pinged your deployment. You successfully connected to MongoDB!")
# except Exception as e:
#     print(e)

# %%
# Client= pymongo.MongoClient("mongodb+srv://rdinesh1702:rdx1717@cluster0.gfpts1u.mongodb.net/?retryWrites=true&w=majority")

# %%
# db = Client["sample_airbnb"]
# coll = db["listingsAndReviews"]

# %%
# data = []

# for i in coll.find({}, {"id":1,"listing_url":1}):
#     data.append(i)

# %%
data = pd.read_csv("C:/Users/rdine/Data_Science/data_science_practise/DataScience_projects/airnb_analyst/data.csv")

# %%
data_1 = pd.DataFrame(data)

# %%
data_1.head()
# Out:
#    Unnamed: 0       _id                            listing_url  \
# 0           0  10051164  https://www.airbnb.com/rooms/10051164
# 1           1  10083468  https://www.airbnb.com/rooms/10083468
# 2           2  10069642  https://www.airbnb.com/rooms/10069642
# 3           3  10059244  https://www.airbnb.com/rooms/10059244
# 4           4  10006546  https://www.airbnb.com/rooms/10006546
#
#                                                name property_type  \
# 0                Catete's Colonial Big Hause Room B         House
# 1                                 Be Happy in Porto          Loft
# 2                Ótimo Apto proximo Parque Olimpico     Apartment
# 3  Ligne verte - à 15 min de métro du centre ville.     Apartment
# 4                           Ribeira Charming Duplex         House
#
#          room_type  bed_type  minimum_nights  maximum_nights  \
# 0     Private room  Real Bed               2            1125
# 1  Entire home/apt  Real Bed               2            1125
# ...
